# %%
from __future__ import absolute_import, division, print_function
import numpy as np
import os
import sys
sys.path.append(os.path.abspath('./'))
import casimir.data.named_entity_recognition as ner
import casimir.optim as optim

# %%
train_file = 'data/ner/eng.train'
dev_file = 'data/ner/eng.testa'
test_file = 'data/ner/eng.testb'

assert os.path.isfile(train_file), 'train_file {} does not exist'.format(train_file)
assert os.path.isfile(dev_file), 'dev_file {} does not exist'.format(dev_file)
assert os.path.isfile(test_file), 'test_file {} does not exist'.format(test_file)

# %%
smoothing_coefficients = [5.0,10.0,20.0]
model_list, logs_list=[],[]
for i in [0,1,2]:
    smoothing_coefficient = smoothing_coefficients[i]
    train_ifo, dev_ifo, test_ifo = ner.create_ner_ifo_from_data(train_file, dev_file, test_file,
                                                                smoothing_coefficient=smoothing_coefficient, num_highest_scores=5)
    l2reg = 0.1 / len(train_ifo)
    print('l2reg:', l2reg)
    l2penalty = optim.L2Penalty(l2reg)

    dim = 2**16 - 1  # hard-coded. All features are hashed onto these dimensions.
    model = np.zeros(dim)

    # Casimir-SVRG, constant smoothing
    optim_options_1 = {'grad_lipschitz_parameter': 32.0, 'initial_smoothing_coefficient': smoothing_coefficient,
                       'warm_start': 'prev-iterate'}
    # Run optimization
    num_passes = 30
    model, logs = optim.optimize_ifo(model, train_ifo, algorithm='casimir_svrg', dev_ifo=dev_ifo, test_ifo=None,
                                     reg_penalties=[l2penalty], num_passes=num_passes, termination_criterion=None, seed=25,
                                     logging=True, verbose=True,
                                     optim_options=optim_options_1)
    model_list.append(model)
    logs_list.append(logs)
# Out:
# l2reg: 7.1219998575600035e-06
# Epoch		Function		Dev_function	Dev_evaluation		Time
# 0.00		14.50188733		15.803692		0.019034		64.01
# 1.00		5.65850349		6.454670		0.606475		246.51
# 2.00		3.02185286		3.447523		0.705213		268.48
# 3.00		2.34379137		2.823032		0.737004		254.37
# 4.00		1.99599260		2.578144		0.747057		253.35
# 5.00		1.78207074		2.448360		0.758443		250.88
# 6.00		1.64900338		2.389441		0.762435		261.20
# 7.00		1.56542304		2.356986		0.767669		284.04
# 8.00		1.50337675		2.340367		0.769170		292.48
# 9.00		1.45915390		2.338355		0.771624		297.58
# 10.00		1.42636726		2.340772		0.773125		302.74
# 11.00		1.39936016		2.347393		0.775523		308.56
# 12.00		1.37769052		2.357343		0.774893		306.51
# 13.00		1.35932925		2.368476		0.773594		315.42
# 14.00		1.34487433		2.381703		0.776163		329.53
# 15.00		1.33111075		2.391337		0.776820		336.96
# 16.00		1.31910095		2.405089		0.777800		353.14
# 17.00		1.30673261		2.415572		0.776180		307.66
# 18.00		1.29636254		2.427496		0.774654		283.70
# 19.00		1.28871071		2.439817		0.775217		274.42
# 20.00		1.27951229		2.450002		0.774764		272.47
# 21.00		1.27220931		2.458651		0.774632		274.89
# 22.00		1.26497633		2.473010		0.773654		250.54
# 23.00		1.25748971		2.480888		0.775008		266.98
# 24.00		1.25189773		2.493219		0.774456		261.92
# 25.00		1.24719492		2.504810		0.772882		264.89
# 26.00		1.24223694		2.515882		0.773456		260.67
# 27.00		1.23813932		2.527402		0.774442		255.22
# 28.00		1.23235231		2.536841		0.776009		277.74
# 29.00		1.22954502		2.548465		0.772732		281.75
# 30.00		1.22673366		2.557573		0.772534		296.81
# l2reg: 7.1219998575600035e-06
# Epoch		Function		Dev_function	Dev_evaluation		Time
# 0.00		14.50188733		15.803692		0.019034		73.78
# 1.00		5.89490676		6.700893		0.601836		256.66
# 2.00		3.31643289		3.776171		0.697645		275.43
# 3.00		2.62640527		3.135001		0.728971		269.08
# 4.00		2.28783708		2.899388		0.743679		267.85
# 5.00		2.07657627		2.771087		0.750736		267.86
# 6.00		1.94242591		2.717623		0.759156		270.32
# 7.00		1.85852135		2.695857		0.761562		267.72
# 8.00		1.79890189		2.691886		0.765487		270.16
# 9.00		1.75603711		2.700281		0.767996		274.51
# 10.00		1.72412908		2.716349		0.767356		271.60
# 11.00		1.69756761		2.727081		0.768191		265.26
# 12.00		1.67770720		2.745859		0.768911		268.90
# 13.00		1.65964398		2.764059		0.769580		246.67
# 14.00		1.64568479		2.783874		0.770184		247.92
# 15.00		1.63384286		2.803496		0.771425		243.19
# 16.00		1.62175653		2.821017		0.771155		238.61
# 17.00		1.61175141		2.839639		0.771534		248.17
# 18.00		1.60433639		2.857796		0.771207		248.11
# 19.00		1.59827023		2.877084		0.771235		246.93
# 20.00		1.59063958		2.893745		0.771244		246.60
# 21.00		1.58433138		2.911516		0.771968		242.27
# 22.00		1.57853393		2.928050		0.772519		246.02
# 23.00		1.57380019		2.944144		0.773252		247.57
# 24.00		1.56873816		2.958667		0.771496		245.28
# 25.00		1.56433593		2.974909		0.771538		244.50
# 26.00		1.56052736		2.994399		0.771824		248.40
# 27.00		1.55790557		3.008585		0.772716		245.07
# 28.00		1.55405938		3.023991		0.772595		250.03
# 29.00		1.55041201		3.041855		0.773785		243.61
# 30.00		1.54734980		3.057089		0.773285		245.30
# l2reg: 7.1219998575600035e-06
# Epoch		Function		Dev_function	Dev_evaluation		Time
# 0.00		14.50188733		15.803692		0.019034		65.55
# 1.00		6.30904204		7.136535		0.597777		246.72
# 2.00		3.79201768		4.300605		0.682995		245.69
# 3.00		3.09331478		3.655685		0.715305		246.81
# 4.00		2.77316218		3.435328		0.727755		248.17
# 5.00		2.57954879		3.327822		0.737649		251.38
# 6.00		2.45918217		3.298435		0.742145		253.33
# 7.00		2.38336194		3.298371		0.749290		250.95
# 8.00		2.33199358		3.315612		0.754948		248.56
# 9.00		2.29802205		3.343079		0.757326		248.95
# 10.00		2.27617018		3.383356		0.758361		235.87
# 11.00		2.25929499		3.420221		0.760286		250.90
# 12.00		2.24744611		3.459140		0.761191		253.53
# 13.00		2.23822187		3.497011		0.762319		250.41
# 14.00		2.23154187		3.537826		0.763499		237.97
# 15.00		2.22470091		3.570955		0.764276		249.11
# 16.00		2.22234389		3.609685		0.765334		248.20
# 17.00		2.21811056		3.639639		0.766100		248.54
# 18.00		2.21496653		3.671138		0.766215		246.88
# 19.00		2.21454388		3.701841		0.765747		248.06
# 20.00		2.21431149		3.735888		0.766381		245.07
# 21.00		2.21378714		3.767198		0.766756		248.42
# 22.00		2.21436768		3.798608		0.765798		250.90
# 23.00		2.21386446		3.827427		0.766444		249.38
# 24.00		2.21255974		3.854681		0.767509		246.58
# 25.00		2.21240166		3.882223		0.767790		243.94
# 26.00		2.21327426		3.910408		0.768599		243.16
# 27.00		2.21231865		3.938044		0.767966		240.15
# 28.00		2.21170903		3.963185		0.766945		236.13
# 29.00		2.21238142		3.986838		0.767850		241.10
# 30.00		2.21225100		4.010726		0.767372		240.78

# %%
import pickle as pkl
pkl.dump( model_list, open( "data/models/e2.model", "wb" ) )
pkl.dump( logs_list, open( "data/logs/e2.log", "wb" ) )

# %%
import matplotlib
import matplotlib.pyplot as plt
smoothing_coefficients = [5.0,10.0,20.0]
logs_array = np.array(logs_list)
logs_array = logs_array[:,1:,:]
iteration = logs_array[0,:,0]

# %%
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
for i in [0,1,2]:
    plt.plot(iteration, logs_array[i,:,1], label='mu='+str(smoothing_coefficients[i]))
plt.xlabel('iteration')
plt.ylabel('train loss')
plt.grid()
plt.legend(loc='upper right', shadow=True)

plt.subplot(1,2,2)
for i in [0,1,2]:
    plt.plot(iteration, logs_array[i,:,3], label='mu='+str(smoothing_coefficients[i]))
plt.xlabel('iteration')
plt.ylabel('F1')
plt.grid()
plt.legend(loc='lower right', shadow=True)
plt.show()
